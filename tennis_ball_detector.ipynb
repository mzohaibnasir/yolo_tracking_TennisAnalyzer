# %% [markdown]
# <a href="https://colab.research.google.com/github/mzohaibnasir/yolo_tracking_TennisAnalyzer/blob/main/tennis_ball_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %% [markdown]
# ## Data Ingestion

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lRVQkcTRjpXNd3JVDKRU")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil  # to move thigs around

shutil.move(
    "tennis-ball-detection-6/train",
    "tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move(
    "tennis-ball-detection-6/test",
    "tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move(
    "tennis-ball-detection-6/valid",
    "tennis-ball-detection-6/tennis-ball-detection-6/valid",
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     815     try:
# --> 816         os.rename(src, real_dst)
#     817     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tennis-ball-detection-6/train' -> 'tennis-ball-detection-6/tennis-ball-detection-6/train/train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-985613d5c0cd> in <cell line: 3>()
#       1 import shutil  # to move thigs around
#       2
# ----> 3 shutil.move(
#       4     "tennis-ball-detection-6/train",
#       5     "tennis-ball-detection-6/tennis-ball-detection-6/train",
#
# /usr/lib/python3.10/shutil.py in move(src, dst, copy_function)
#     834             rmtree(src)
#     835         else:
# ...

# %% [markdown]
# ## training

# %%
! yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640


# dataset location is frmo roboflow
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
